# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Adaml\OneDrive - TU Eindhoven\University\Year 2\Q3\DBL Process Mining\BPI Challenge 2017.csv")

# %%
df.head(15)
# Out:
#                      case                     event                startTime  \
# 0   Application_652823628      A_Create Application  2016/01/01 10:51:15.304
# 1   Application_652823628               A_Submitted  2016/01/01 10:51:15.352
# 2   Application_652823628                 A_Concept  2016/01/01 10:52:36.413
# 3   Application_652823628    W_Complete application  2016/01/02 11:45:22.429
# 4   Application_652823628                A_Accepted  2016/01/02 12:23:04.299
# 5   Application_652823628            O_Create Offer  2016/01/02 12:29:03.994
# 6   Application_652823628                 O_Created  2016/01/02 12:29:05.354
# 7   Application_652823628  O_Sent (mail and online)  2016/01/02 12:30:28.606
# 8   Application_652823628       W_Call after offers  2016/01/02 12:30:28.631
# 9   Application_652823628                A_Complete  2016/01/02 12:30:28.633
# 10  Application_652823628    W_Validate application  2016/01/13 14:10:55.145
# ...

# %%
asd = df.groupby("case")
len(asd.groups)
# Out:
# 31509

# %%
df['LoanGoal'].value_counts()
# Out:
# Car                       161959
# Home improvement          137441
# Existing loan takeover    103858
# Other, see explanation     51779
# Unknown                    40940
# Not speficied              18991
# Remaining debt home        18352
# Extra spending limit       10637
# Caravan / Camper            6363
# Motorcycle                  4728
# Boat                        3482
# Tax payments                2618
# Business goal                500
# Debt restructuring            23
# Name: LoanGoal, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 561671 entries, 0 to 561670
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   case                   561671 non-null  object
#  1   event                  561671 non-null  object
#  2   startTime              561671 non-null  object
#  3   completeTime           561671 non-null  object
#  4   LoanGoal               561671 non-null  object
#  5   ApplicationType        561671 non-null  object
#  6   RequestedAmount        561671 non-null  float64
#  7   Action                 561671 non-null  object
#  8   FirstWithdrawalAmount  413046 non-null  float64
#  9   Accepted               413046 non-null  object
#  10  NumberOfTerms          413046 non-null  float64
#  11  OfferID                381537 non-null  object
#  12  org:resource           561671 non-null  object
#  13  MonthlyCost            413046 non-null  float64
# ...
