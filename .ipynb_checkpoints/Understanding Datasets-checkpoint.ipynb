# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Adaml\OneDrive - TU Eindhoven\University\Year 2\Q3\DBL Process Mining\BPI Challenge 2017.csv")

# %%
df
# Out:
#                           case                     event  \
# 0        Application_652823628      A_Create Application
# 1        Application_652823628               A_Submitted
# 2        Application_652823628                 A_Concept
# 3        Application_652823628    W_Complete application
# 4        Application_652823628                A_Accepted
# ...                        ...                       ...
# 561666  Application_1350494635  O_Sent (mail and online)
# 561667  Application_1350494635       W_Call after offers
# 561668  Application_1350494635                A_Complete
# 561669  Application_1350494635               A_Cancelled
# 561670  Application_1350494635               O_Cancelled
#
#                       startTime             completeTime  \
# 0       2016/01/01 10:51:15.304  2016/01/01 10:51:15.304
# 1       2016/01/01 10:51:15.352  2016/01/01 10:51:15.352
# 2       2016/01/01 10:52:36.413  2016/01/01 10:52:36.413
# 3       2016/01/02 11:45:22.429  2016/01/02 11:45:22.429
# 4       2016/01/02 12:23:04.299  2016/01/02 12:23:04.299
# ...                         ...                      ...
# 561666  2017/01/02 20:27:20.453  2017/01/02 20:27:20.453
# 561667  2017/01/02 20:27:20.472  2017/01/02 20:27:20.472
# 561668  2017/01/02 20:27:20.474  2017/01/02 20:27:20.474
# 561669  2017/01/16 10:51:21.114  2017/01/16 10:51:21.114
# 561670  2017/01/16 10:51:21.139  2017/01/16 10:51:21.139
#
#                       LoanGoal ApplicationType  RequestedAmount       Action  \
# 0       Existing loan takeover      New credit          20000.0      Created
# 1       Existing loan takeover      New credit          20000.0  statechange
# 2       Existing loan takeover      New credit          20000.0  statechange
# 3       Existing loan takeover      New credit          20000.0     Obtained
# 4       Existing loan takeover      New credit          20000.0  statechange
# ...                        ...             ...              ...          ...
# 561666        Home improvement      New credit          20000.0  statechange
# 561667        Home improvement      New credit          20000.0     Obtained
# 561668        Home improvement      New credit          20000.0  statechange
# 561669        Home improvement      New credit          20000.0  statechange
# 561670        Home improvement      New credit          20000.0  statechange
#
#         FirstWithdrawalAmount Accepted  NumberOfTerms           OfferID  \
# 0                         NaN      NaN            NaN               NaN
# 1                         NaN      NaN            NaN               NaN
# 2                         NaN      NaN            NaN               NaN
# 3                         NaN      NaN            NaN               NaN
# 4                         NaN      NaN            NaN               NaN
# ...                       ...      ...            ...               ...
# 561666                20000.0    False           77.0  Offer_1580299144
# 561667                20000.0    False           77.0  Offer_1580299144
# 561668                20000.0    False           77.0  Offer_1580299144
# 561669                20000.0    False           77.0  Offer_1580299144
# 561670                20000.0    False           77.0  Offer_1580299144
#
#        org:resource  MonthlyCost  EventOrigin                EventID Selected  \
# 0            User_1          NaN  Application  Application_652823628      NaN
# 1            User_1          NaN  Application   ApplState_1582051990      NaN
# 2            User_1          NaN  Application    ApplState_642383566      NaN
# 3           User_17          NaN     Workflow    Workitem_1875340971      NaN
# 4           User_52          NaN  Application     ApplState_99568828      NaN
# ...             ...          ...          ...                    ...      ...
# 561666      User_96       297.81        Offer  OfferState_1959881309    False
# 561667      User_96       297.81     Workflow     Workitem_358206591    False
# 561668      User_96       297.81  Application   ApplState_1120616436    False
# 561669      User_28       297.81  Application   ApplState_1869071797    False
# 561670      User_28       297.81        Offer   OfferState_420066181    False
#
#         CreditScore  OfferedAmount
# 0               NaN            NaN
# 1               NaN            NaN
# 2               NaN            NaN
# 3               NaN            NaN
# 4               NaN            NaN
# ...             ...            ...
# 561666          0.0        20000.0
# 561667          0.0        20000.0
# 561668          0.0        20000.0
# 561669          0.0        20000.0
# 561670          0.0        20000.0
#
# [561671 rows x 19 columns]

# %%
asd = df.groupby("case")
len(asd.groups)
# Out:
# 31509

# %%
df['LoanGoal'].value_counts()
# Out:
# Car                       161959
# Home improvement          137441
# Existing loan takeover    103858
# Other, see explanation     51779
# Unknown                    40940
# Not speficied              18991
# Remaining debt home        18352
# Extra spending limit       10637
# Caravan / Camper            6363
# Motorcycle                  4728
# Boat                        3482
# Tax payments                2618
# Business goal                500
# Debt restructuring            23
# Name: LoanGoal, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 561671 entries, 0 to 561670
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   case                   561671 non-null  object
#  1   event                  561671 non-null  object
#  2   startTime              561671 non-null  object
#  3   completeTime           561671 non-null  object
#  4   LoanGoal               561671 non-null  object
#  5   ApplicationType        561671 non-null  object
#  6   RequestedAmount        561671 non-null  float64
#  7   Action                 561671 non-null  object
#  8   FirstWithdrawalAmount  413046 non-null  float64
#  9   Accepted               413046 non-null  object
#  10  NumberOfTerms          413046 non-null  float64
#  11  OfferID                381537 non-null  object
#  12  org:resource           561671 non-null  object
#  13  MonthlyCost            413046 non-null  float64
#  14  EventOrigin            561671 non-null  object
#  15  EventID                561671 non-null  object
#  16  Selected               413046 non-null  object
#  17  CreditScore            413046 non-null  float64
#  18  OfferedAmount          413046 non-null  float64
# dtypes: float64(6), object(13)
# memory usage: 81.4+ MB
